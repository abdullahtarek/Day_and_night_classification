# %%
import cv2
import numpy as np
import os
from glob import glob
import matplotlib.pyplot as plt

# %%
training_folder="day_night_images\\training\\"
testing_folder="day_night_images/test\\"
def read_data(folder_path):
    images=[]
    label=[]
    for img in glob(folder_path+"*/*.jpg"):
        images.append(cv2.imread(img))
        label.append(int(img.split('\\')[-2]== "day"))
    return images,np.array(label)

# %%
training_images,training_labels = read_data(training_folder)

# %%
plt.imshow(cv2.cvtColor(training_images[120], cv2.COLOR_BGR2RGB))
plt.show()

# %%
night_average_brightness=[]
day_average_brightness=[]
for index, img in enumerate(training_images):
    img=cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
    average_brightness = np.mean(img[2])
    if training_labels[index] ==1:
        day_average_brightness.append(average_brightness)
    else:
        night_average_brightness.append(average_brightness)

# %%
plt.boxplot([night_average_brightness,day_average_brightness],showmeans=True)
plt.xticks([1,2] , ["night","day"])
plt.hlines(y=80)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-54-83ffde117e0c> in <module>()
#       1 plt.boxplot([night_average_brightness,day_average_brightness],showmeans=True)
#       2 plt.xticks([1,2] , ["night","day"])
# ----> 3 plt.hlines(y=80)
#       4
#       5 plt.show()
#
# TypeError: hlines() missing 2 required positional arguments: 'xmin' and 'xmax'
